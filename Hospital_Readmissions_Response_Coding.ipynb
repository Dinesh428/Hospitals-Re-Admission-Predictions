# %% [markdown]
# <h1>Hospital Readmissions Data preperation(Response Coding)</h1>

# %%
#importing pickle files to read train and test files
import pickle

f_bow=open('X_train','rb')
X_train=pickle.load(f_bow)
f_bow.close()


f_bow=open('X_test','rb')
X_test=pickle.load(f_bow)
f_bow.close()

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing

def get_gv_fea_dict(alpha, feature, df):
    value_count = X_train[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in ['NO','Admitted']:
            cls_cnt = X_train.loc[(X_train['readmitted']==k) & (X_train[feature]==i)]
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 20*alpha))
        # we are adding the features to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

def get_gv_feature(alpha, feature, df):
    
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = X_train[feature].value_counts()
    
    
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9])
#             gv_fea.append([-1,-1])
    return pd.DataFrame(gv_fea,columns=['NO_'+feature,'Admitted_'+feature])

# %% [markdown]
# <h2>For all category features, Response coding is performed</h2>

# %%
alpha = 1
import numpy as np
import pandas as pd
train_df=pd.DataFrame()
test_df=pd.DataFrame()
# train gene feature
train_gene_feature_responseCoding = (get_gv_feature(alpha, "age", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "age", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "gender", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "gender", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "race", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "race", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "admission_type_id", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "admission_type_id", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "discharge_disposition_id", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "discharge_disposition_id", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "admission_source_id", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "admission_source_id", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "medical_specialty", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "medical_specialty", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "diag_1", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "diag_1", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "diag_2", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "diag_2", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "diag_3", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "diag_3", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %% [markdown]
# Response coding for all medications performed

# %%
train_gene_feature_responseCoding = (get_gv_feature(alpha, "max_glu_serum", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "max_glu_serum", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "A1Cresult", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "A1Cresult", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "metformin", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "metformin", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "repaglinide", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "repaglinide", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "nateglinide", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "nateglinide", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "chlorpropamide", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "chlorpropamide", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "glimepiride", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "glimepiride", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "glipizide", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "glipizide", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "glyburide", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "glyburide", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "tolbutamide", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "tolbutamide", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "pioglitazone", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "pioglitazone", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "rosiglitazone", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "rosiglitazone", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)


train_gene_feature_responseCoding = (get_gv_feature(alpha, "acarbose", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "acarbose", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "miglitol", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "miglitol", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "troglitazone", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "troglitazone", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "tolazamide", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "tolazamide", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "insulin", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "insulin", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "glyburide-metformin", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "glyburide-metformin", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "change", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "change", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

train_gene_feature_responseCoding = (get_gv_feature(alpha, "diabetesMed", X_train))
train_df=pd.concat((train_df.reset_index(drop=True),train_gene_feature_responseCoding.reset_index(drop=True)), axis=1)
test_gene_feature_responseCoding = (get_gv_feature(alpha, "diabetesMed", X_test))
test_df=pd.concat((test_df.reset_index(drop=True),test_gene_feature_responseCoding.reset_index(drop=True)), axis=1)

# %%
train_df=pd.concat((train_df.reset_index(drop=True),X_train['time_in_hospital'].reset_index(drop=True)), axis=1)
train_df=pd.concat((train_df.reset_index(drop=True),X_train['num_lab_procedures'].reset_index(drop=True)), axis=1)
train_df=pd.concat((train_df.reset_index(drop=True),X_train['num_procedures'].reset_index(drop=True)), axis=1)
train_df=pd.concat((train_df.reset_index(drop=True),X_train['num_medications'].reset_index(drop=True)), axis=1)
train_df=pd.concat((train_df.reset_index(drop=True),X_train['number_outpatient'].reset_index(drop=True)), axis=1)
train_df=pd.concat((train_df.reset_index(drop=True),X_train['number_emergency'].reset_index(drop=True)), axis=1)
train_df=pd.concat((train_df.reset_index(drop=True),X_train['number_inpatient'].reset_index(drop=True)), axis=1)
train_df=pd.concat((train_df.reset_index(drop=True),X_train['number_diagnoses'].reset_index(drop=True)), axis=1)

test_df=pd.concat((test_df.reset_index(drop=True),X_test['time_in_hospital'].reset_index(drop=True)), axis=1)
test_df=pd.concat((test_df.reset_index(drop=True),X_test['num_lab_procedures'].reset_index(drop=True)), axis=1)
test_df=pd.concat((test_df.reset_index(drop=True),X_test['num_procedures'].reset_index(drop=True)), axis=1)
test_df=pd.concat((test_df.reset_index(drop=True),X_test['num_medications'].reset_index(drop=True)), axis=1)
test_df=pd.concat((test_df.reset_index(drop=True),X_test['number_outpatient'].reset_index(drop=True)), axis=1)
test_df=pd.concat((test_df.reset_index(drop=True),X_test['number_emergency'].reset_index(drop=True)), axis=1)
test_df=pd.concat((test_df.reset_index(drop=True),X_test['number_inpatient'].reset_index(drop=True)), axis=1)
test_df=pd.concat((test_df.reset_index(drop=True),X_test['number_diagnoses'].reset_index(drop=True)), axis=1)

# %%
train_df.head()
# Out:
#      NO_age  Admitted_age  NO_gender  Admitted_gender   NO_race  \
# 0  0.840224      0.159776   0.818941         0.181059  0.816101
# 1  0.795399      0.204601   0.818941         0.181059  0.816101
# 2  0.825581      0.174419   0.818941         0.181059  0.816101
# 3  0.795399      0.204601   0.818941         0.181059  0.816101
# 4  0.803946      0.196054   0.818941         0.181059  0.816101
#
#    Admitted_race  NO_admission_type_id  Admitted_admission_type_id  \
# 0       0.183899              0.812170                    0.187830
# 1       0.183899              0.844283                    0.155717
# 2       0.183899              0.812170                    0.187830
# 3       0.183899              0.812170                    0.187830
# 4       0.183899              0.817070                    0.182930
#
#    NO_discharge_disposition_id  Admitted_discharge_disposition_id  \
# 0                     0.854582                           0.145418
# ...

# %%
test_df.head()
# Out:
#      NO_age  Admitted_age  NO_gender  Admitted_gender   NO_race  \
# 0  0.795399      0.204601   0.818941         0.181059  0.816101
# 1  0.847528      0.152472   0.818941         0.181059  0.816101
# 2  0.847528      0.152472   0.823433         0.176567  0.816101
# 3  0.803946      0.196054   0.823433         0.176567  0.816101
# 4  0.840224      0.159776   0.823433         0.176567  0.816101
#
#    Admitted_race  NO_admission_type_id  Admitted_admission_type_id  \
# 0       0.183899              0.821010                    0.178990
# 1       0.183899              0.812170                    0.187830
# 2       0.183899              0.844283                    0.155717
# 3       0.183899              0.812170                    0.187830
# 4       0.183899              0.812170                    0.187830
#
#    NO_discharge_disposition_id  Admitted_discharge_disposition_id  \
# 0                     0.854582                           0.145418
# ...

# %%
print('Training data size is',train_df.shape[0])

print('Testing data size is',test_df.shape[0])
# Out:
# Training data size is 42821
# Testing data size is 18353

# %%
import pickle

f_bow=open('test_df_R','wb')
pickle.dump(test_df, f_bow)
f_bow.close()
f_bow=open('test_df_R','rb')
test_df=pickle.load(f_bow)
f_bow.close()


f_bow=open('train_df_R','wb')
pickle.dump(train_df, f_bow)
f_bow.close()
f_bow=open('train_df_R','rb')
train_df=pickle.load(f_bow)
f_bow.close()
